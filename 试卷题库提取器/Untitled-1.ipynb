# %%
from tkinter import *
import tkinter.filedialog

from docx import Document
import xlwt
import re



root=Tk()
filename=""
def opent():
    filenames=tkinter.filedialog.askopenfilename()
    filename=filenames
    lb.config(text=filename)

def doexcel():
    lb.config(text='OK!')
    xl = xlwt.Workbook(encoding='utf-8')
    # 创建一个sheet1对象,第二个参数是指单元格是否允许重设置，默认为False
    sheet1 = xl.add_sheet('单选题', cell_overwrite_ok=True)
    sheet2 = xl.add_sheet('多选题', cell_overwrite_ok=True)
    sheet3 = xl.add_sheet('判断题', cell_overwrite_ok=True)
    sheet4 = xl.add_sheet('问答题', cell_overwrite_ok=True)
    # 初始化样式
    style = xlwt.XFStyle()
    # 为样式创建字体
    font = xlwt.Font()
    font.name = 'Times New Roman'
    # 黑体
    font.bold = True
    # 下划线
    font.underline = False
    # 斜体字
    font.italic = True
    # 设定样式
    style.font = font
    # 第一个参数代表行，第二个参数是列，第三个参数是内容，第四个参数是格式
    # 初始化
    sheet1.write(0, 0, '序号', style)
    sheet1.write(0, 1, '题目', style)
    sheet1.write(0, 2, 'A', style)
    sheet1.write(0, 3, 'B', style)
    sheet1.write(0, 4, 'C', style)
    sheet1.write(0, 5, 'D', style)

    sheet2.write(0, 0, '序号', style)
    sheet2.write(0, 1, '题目', style)
    sheet2.write(0, 2, 'A', style)
    sheet2.write(0, 3, 'B', style)
    sheet2.write(0, 4, 'C', style)
    sheet2.write(0, 5, 'D', style)

    sheet3.write(0, 0, '序号', style)
    sheet3.write(0, 1, '题目', style)

    sheet4.write(0, 0, '序号', style)
    sheet4.write(0, 1, '题目', style)
    # sheet1.write(1, 0, '带样式的写入', style)


    # 段落计数器
    paragraph=0

    # 选项计数器
    # abcd=0
    # 行
    item=0
    title=0
    a,b,c,d,e,f=0,0,0,0,0,0

    # 读取DOCX试卷文本
    doc1=Document(r'C:\Users\zero\.ipython\试卷题库提取器\test.docx')
    for p in doc1.paragraphs:
        
        paragraph+=1
    

        print(p.text)
    
        print(title)
        if re.search(r'单选题', p.text):       #.span()
            title=1
            item=0
        elif re.search(r'多选题', p.text):       #.span()
            title=2
            item=0
        elif re.search(r'判断题', p.text):       #.span()
            title=3
            item=0
        elif re.search(r'问答题', p.text):       #.span()
            title=4
            item=0
        elif re.search(r'填空题', p.text):       #.span()
            title=5
            item=0
        else :
            pass

        # result1 = re.findall(r'\d{1,2}\.\w+\s',p.text)
        # 现在开始处理单选题1-100
        if title == 1:
            # 查找数字开头的题目并返回查找结果
            result1 = re.findall(r'^\d{1,3}\..*',p.text)
            
            if result1:
                item=item+1
                # 如果找到单选题条目的题目内容
                for i in result1:
                    # 写入序号
                    sheet1.write(item, 0, item)
                    #替换题目开头的数字
                    sub1 = re.sub(r'^\d{1,3}\.', "+",i)
                    sheet1.write(item, 1, sub1)
                    # abcd=0
                
            else :
                # 用了4个分隔区分AB选项
                result_A = re.findall(r'A\..*    ',p.text)
                result_B = re.findall(r'B\..*',p.text)
                result_C = re.findall(r'C\..*    ',p.text)
                result_D = re.findall(r'D\..*',p.text)
                
                for a in result_A:
                    sub1 = re.sub(r'A\.', "",a)
                    sheet1.write(item, 2, sub1)
                
            
                for b in result_B:
                    sub1 = re.sub(r'B\.', "",b)
                    sheet1.write(item, 3, sub1)

            
                for c in result_C:
                    sub1 = re.sub(r'C\.', "",c)
                    sheet1.write(item, 4, sub1)

            
                for d in result_D:
                    sub1 = re.sub(r'D\.', "",d)
                    sheet1.write(item, 5, sub1)
        

        # ------------------------------------------------------------------------------------
        # 现在开始处理多选题
        elif title == 2:
            # 查找数字开头的题目并返回查找结果
            result1 = re.findall(r'^\d{1,3}\..*',p.text)
            
            if result1:
                item=item+1
                # 如果找到单选题条目的题目内容
                for i in result1:
                    # 写入序号
                    sheet2.write(item, 0, item)
                    #替换题目开头的数字
                    sub1 = re.sub(r'^\d{1,3}\.', "+",i)
                    sheet2.write(item, 1, sub1)
                    # abcd=0
                
            else :
                # 用了4个分隔区分AB选项
                result_A = re.findall(r'A\..*    ',p.text)
                result_B = re.findall(r'B\..*',p.text)
                result_C = re.findall(r'C\..*    ',p.text)
                result_D = re.findall(r'D\..*',p.text)
                
                for a in result_A:
                    sub1 = re.sub(r'A\.', "",a)
                    sheet2.write(item, 2, sub1)
                
            
                for b in result_B:
                    sub1 = re.sub(r'B\.', "",b)
                    sheet2.write(item, 3, sub1)

            
                for c in result_C:
                    sub1 = re.sub(r'C\.', "",c)
                    sheet2.write(item, 4, sub1)

            
                for d in result_D:
                    sub1 = re.sub(r'D\.', "",d)
                    sheet2.write(item, 5, sub1)         
                
        # ------------------------------------------------------------------------------------
        # 现在开始处理判断题
        elif title == 3:
            # 查找数字开头的题目并返回查找结果
            result1 = re.findall(r'^\d{1,3}\..*',p.text)
            
            if result1:
                item=item+1
                # 如果找到单选题条目的题目内容
                for i in result1:
                    # 写入序号
                    sheet3.write(item, 0, item)
                    #替换题目开头的数字
                    sub1 = re.sub(r'^\d{1,3}\.', "+",i)
                    sheet3.write(item, 1, sub1)

        # ------------------------------------------------------------------------------------
        # 现在开始处理问答题
        elif title == 4:
            # 查找数字开头的题目并返回查找结果
            result1 = re.findall(r'^\d{1,3}\..*',p.text)
            
            if result1:
                item=item+1
                # 如果找到单选题条目的题目内容
                for i in result1:
                    # 写入序号
                    sheet4.write(item, 0, item)
                    #替换题目开头的数字
                    sub1 = re.sub(r'^\d{1,3}\.', "+",i)
                    sheet4.write(item, 1, sub1)

    # 保存文件
    xl.save(r'C:\Users\zero\.ipython\Re_test试卷题库提取器m.xls')




lb=Label(root,text="filename")
lb.pack()

btn=Button(root,text="请选择试卷！",command=opent)
btn.pack()

btn=Button(root,text="提取.docx试卷到.xls文件",command=doexcel)
btn.pack()


root.mainloop()
# Out:
# 《国家电网公司变电五项通用制度》考试试卷
# 0
# 检测类（B卷）
# 0
# 一、单选题(每题0.25分，计25分)
# 0
# 1.接地引下线导通测试宜选用专用仪器，分辨率不大于（）。
# 1
#   A.1mΩ         B.2mΩ
# 1
#   C.3mΩ         D.4mΩ
# 1
# 2.状况良好的设备接地引下线导通测试值应在（）以下。
# 1
#   A.50mΩ            B.80mΩ
# 1
#   C.100mΩ           D.120mΩ
# 1
# 3.接地引下线导通测试值在（）间的设备状况尚可，宜在以后例行测试中重点关注其变化，重要的设备宜在适当时候检查处理。
# 1
#   A.10mΩ-50mΩ        B.50mΩ-200mΩ
# 1
#   C.200mΩ-1Ω         D.1Ω-2Ω
# 1
# 4.直流电桥法测接地导通时，测试电流线应在测试电压端的（）。
# 1
#   A.外侧         B.内侧
# 1
#   C.同侧         D.反侧
# 1
# 5.接地阻抗测试采用异频电流法测试接地装置的工频特性参数，试验电流宜在（）。
# 1
#   A.小于3  A         B.3  A-20  A
# 1
#   C.20  A-50  A        D.不小于50  A
# 1
# 6.接地阻抗测量中，当远距离放线有困难时，建议使用夹角法进行测量，测量时电流极与被试接地装置边缘的距离  D  C  G在土壤电阻率不均匀地区  D  C  G可取（）。
# 1
#   A.2  D          B.3  D
# 1
#   C.4  D          D.5  D
# 1
# 7.无论哪种接地阻抗测试方法，都要求电流线和电位线之间保持（）的距离，以尽量减小电流线与电位线之间的影响互感。
# 1
#   A.尽量近           B.尽量远
# 1
#   C.适中             D.一定
# 1
# 8.接地阻抗测量，电位极应紧密而不松动地插入土壤（）。
# 1
#   A.20  Cm以上         B.20  Cm以内
# 1
#   C.50  Cm以上         D.50  Cm以内
# 1
# 9.接地阻抗测试中，电流极的电阻值应（）。
# 1
#   A.尽量大         B.尽量小
# 1
#   C.无所谓         D.适当
# 1
# 10.土壤电阻率测试方法一般为（）。
# 1
#   A.两级法         B.三极法
# 1
#   C.四极法         D.电位降法
# 1
# 11.改变（），可反映不同深度的土壤电阻率ρ的变化。
# 1
#   A.电位极的位置;            B.电流极的位置
# 1
#   C.被试电极的埋设深度       D.电流极的深度
# 1
# 12.四级等距法中，可根据级间距离  A及接地阻抗测试仪测试得到的接地阻抗值R，得到被测场地的视在土壤电阻率ρ等于(）。
# 1
#   A.π  AR           B.2π  AR
# 1
#   C.  AR             D.2  AR
# 1
# 13.土壤电阻率测试一般宜在连续天晴（）天后或在干燥季节进行。
# 1
#   A.2            B.3
# 1
#   C.4            D.5
# 1
# 14.跨步电压和接触电压测量试验装置的低压回路中应有（）个串联电源开关，并加装过载自动跳闸装置。
# 1
#   A.1        B.2
# 1
#   C.3        D.4
# 1
# 15.跨步电压和接触电压测量，测试电极可用直径8-10mm、长约（）mm的圆钢。
# 1
#   A.100            B.200
# 1
#   C.300            D.400
# 1
# 16.串联补偿装置不平衡电流试验前对被试电容器组织（）。
# 1
#   A.放电         B.逐只放电
# 1
#   C.充分放电     D.逐只充分放电
# 1
# 17.串联补偿装置不平衡电流测量，根据测试电流与额定电流的比例关系，额定不平衡电流I1为（）（其中：I  E为串补装置运行的额定电流；I0为模拟测试时的不平衡电流值；I  C为模拟测试时的试验电流）。
# 1
#   A.I  E*I0/I  C        B.I  E*I  C/I0
# 1
#   C.I  C*I0/I  E        D.I  E*I  C*I0
# 1
# 18.现场污秽评估应在（）进行。
# 1
#   A.现场              B.标准实验室
# 1
#   C.试验大厅          D.变电站
# 1
# 19.附近（）km范围内增加了新的污染源时，应进行一次现场污秽度评估。
# 1
#   A.10           B.15
# 1
#   C.20           D.25
# 1
# 20.现场污秽度划分为（）个等级。
# 1
#   A.3         B.4
# 1
#   C.5         D.6
# 1
# 21.绝缘子污秽取样时，污秽取样单片普通型U70  B/146盘型绝缘子所用蒸馏水水量为（）ml。
# 1
#   A.200           B.300
# 1
#   C.400           D.500
# 1
# 22.污秽取样所用蒸馏水的电导率应小于（）μS/  Cm。
# 1
#   A.10            B.20
# 1
#   C.30            D.40
# 1
# 23.电压等级500kV，绝缘子绝缘电阻低于（）MΩ，判为劣化（零值）绝缘子。
# 1
#   A.200           B.300
# 1
#   C.400           D.500
# 1
# 24.喷水分级法将防污闪涂料表面的憎水性状态分为（）级。
# 1
#   A.5           B.6
# 1
#   C.7           D.8
# 1
# 25.硅橡胶的憎水性检测所用喷水装置采用质量较好的喷壶，应可以方便﹑稳定地调节出雾状水流，每次喷水量为（）mL。
# 1
#   A.0.5～1        B.0.6～1
# 1
#   C.0.7～1        D.0.8～1
# 1
# 26.硅橡胶的憎水性检测时，喷水装置约每秒喷水一次，共喷射（）次，喷射方向尽量垂直于试品表面。
# 1
#   A.20            B.25
# 1
#   C.30            D.35
# 1
# 27.机械弯曲破坏负荷试验一般应在（）℃的室温下进行。
# 1
#   A.10~20         B.10~35
# 1
#   C.15~25         D.15~35
# 1
# 28.机械弯曲破坏负荷试验，施加负荷时，在规定的弯曲破坏负荷（）以前，应迅速平稳地（15s～45s时间内）增加负荷。
# 1
#   A.20%          B.30%
# 1
#   C.40%          D.50%
# 1
# 29.支柱瓷绝缘子孔隙性试验中，实验室试验用装置设备应留有足够的密闭空间，用于放置（）%的红色或紫罗兰色次甲基染料甲醇或乙醇溶液和破碎后的支柱瓷绝缘子试样。
# 1
#   A.3         B.4
# 1
#   C.5         D.6
# 1
# 30.支柱瓷绝缘子孔隙性试验中,实验室试验用装置设备应留有足够的密闭空间,该密闭空间也应提供不小于（）N/m2的压力，保证试样各个方向的压力一致。
# 1
#   A.10  E6         B.15  E6
# 1
#   C.20  E6         D.25  E6
# 1
# 31.甲酚红试剂配置时，将甲酚红研细，溶于（）95%乙醇中。
# 1
#   A.100ml         B.200ml
# 1
#   C.300ml         D.400ml
# 1
# 32.绝缘油酸值检测所用氢氧化钾乙醇溶液保存不宜过长，当氢氧化钾乙醇溶液变（）或产生沉淀时，应对其清液重新进行标定后方可使用。
# 1
#   A.黄          B.红
# 1
#   C.绿          D.灰
# 1
# 33.绝缘油击穿电压检测所用电压表精度不低于（）级。
# 1
#   A.0.5        B.1.0
# 1
#   C.1.5        D.2.0
# 1
# 34.全自动绝缘油击穿电压测定仪电极任一部分离杯壁或搅拌器不小于（）mm。
# 1
#   A.12          B.13
# 1
#   C.14          D.15
# 1
# 35.全自动绝缘油击穿电压测定仪步进变压器电压增长值不能超过预期击穿电压的（）%。
# 1
#   A.2          B.3
# 1
#   C.4          D.5
# 1
# 36.110kV电压等级设备运行油击穿电压试验值应该大于等于（）。
# 1
#   A.35          B.40
# 1
#   C.50          D.60
# 1
# 37.220kV设备，其绝缘油介质损耗因数应小于等于（）。
# 1
#   A.0.02            B.0.03
# 1
#   C.0.04            D.0.05
# 1
# 38.绝缘油含气量检测（气相色谱法）N2的最小检测浓度应小于等于（）uL/L。
# 1
#   A.1          B.5
# 1
#   C.25         D.50
# 1
# 39.绝缘油含气量检测（气相色谱法）中,使用机械振荡脱气法时，抽取（）高纯氩气注入油样中。
# 1
#   A.5ml           B.10ml
# 1
#   C.15ml          D.20ml
# 1
# 40.绝缘油含气量检测（气相色谱法）中,使用机械振荡脱气法时,将注入氩气的油样在振荡后静置（）。
# 1
#   A.10min           B.20min
# 1
#   C.30min           D.40min
# 1
# 41.当油中含气量超过标准时，应进行（）处理。
# 1
#   A.真空脱气          B.滤油
# 1
#   C.换油             D.油再生
# 1
# 42.绝缘油含气量检测（真空压差法）中，电子真空计法仪器测量系统各部件（容器、阀体、管道等）在测试过程中，因承受高真空引起空气渗漏而造成含气量测定值偏大不大于（）%。
# 1
#   A.0.1            B.0.2
# 1
#   C.0.3            D.0.4
# 1
# 43.绝缘油含气量检测（真空压差法）中，U形油柱压差计法时，若油中含气量小于3%，大于1%，其测试结果的相对误差应小于（）。
# 1
#   A.3%           B.5%
# 1
#   C.6%           D.10%
# 1
# 44.绝缘油水分检测（库伦法）中，220kV设备绝缘油水分不超过（）m  G/L为合格。
# 1
#   A.15        B.25
# 1
#   C.35        D.45
# 1
# 45.绝缘油水分检测（库伦法）中，110（66）kV及以下设备绝缘油水分不超过（）m  G/L为合格。
# 1
#   A.15          B.25
# 1
#   C.35          D.45
# 1
# 46.全自动绝缘油界面张力仪分辨率要求为（）mN/m。
# 1
#   A.0.1           B.0.2
# 1
#   C.0.3           D.0.4
# 1
# 47.绝缘油界面张力检测所用中速滤纸直径为（）mm。
# 1
#   A.50             B.100
# 1
#   C.150;           D.200
# 1
# 48.绝缘油界面张力检测再现性要求2个实验室对同一样品的测定结果之差，不应该超过平均值的（）%。
# 1
#   A.2          B.3
# 1
#   C.4          D.5
# 1
# 49.调节液相色谱仪建立工作状况，其UV检测器选择（）nm波长进行检测。
# 1
#   A.275             B.280
# 1
#   C.285             D.290
# 1
# 50.绝缘油中T501抗氧化剂含量检测（红外光谱法）,将两次加热加白土处理所得澄清油缓慢注满液体吸收池，进行测试，若在（）  Cm-1处没有吸收峰，则认为T501已脱干净。
# 1
#   A.3600        B.3650
# 1
#   C.3700        D.3750
# 1
# 51.全自动绝缘油体积电阻率测试仪高阻测量正负误差应不大于（）%。
# 1
#   A.5               B.10
# 1
#   C.15              D.20
# 1
# 52.全自动绝缘油体积电阻率测试仪空杯电容值为（）p  F正负lp  F。
# 1
#   A.20             B.30
# 1
#   C.40             D.50
# 1
# 53.绝缘油体积电阻率检测，取（）次有效测量值的平均值作为样品的体积电阻率试验值，保留两位有效数字。
# 1
#   A.2             B.3
# 1
#   C.4             D.5
# 1
# 54.绝缘油颗粒数检测中，500kV及以上变压器、电抗器油中大于5µm污染颗粒数不超过（）个/100mL，则认为试验合格。
# 1
#   A.1000             B.2000
# 1
#   C.3000             D.4000
# 1
# 55.绝缘油铜金属含量检测在仪器最佳工作参数条件下，以硝酸（2＋98）溶液作为空白，对铜元素浓度分别为1.00μ  G/ml、3.00μ  G/ml、5.00μ  G/ml和10.0μ  G/ml的工作溶液进行测定，以铜元素的浓度值为横坐标，铜元素的测定响应值为纵坐标，制作铜元素的校准曲线。要求校准曲线的线性相关系数大于（）。
# 1
#   A.0.996             B.0.997
# 1
#   C.0.998             D.0.999
# 1
# 56.绝缘油铜金属含量检测细则，适用于（）变电站的变压器、电抗器等充油电气设备。
# 1
#   A.35kV及以上                B.66kV及以上
# 1
#   C.110kV及以上               D.220kV及以上
# 1
# 57.母线电容电流待测设备要求被测系统处于（）状态。
# 1
#   A.检修                 B.冷备用
# 1
#   C.热备用               D.运行
# 1
# 58.母线电容电流检测安全要求应在良好的天气下进行，如遇雷、雨、雪、雾不得进行该项工作，风力大于（）级时，不宜进行该项工作。
# 1
#   A.3                   B.4
# 1
#   C.5                   D.6
# 1
# 59.低于（）可以开始进行测试工作。将电容电流测试仪电流输出端接于电压互感器开口三角两端。
# 1
#   A.2V               B.3V
# 1
#   C.4V               D.5V
# 1
# 60.母线电容电流检测结果应符合以下要求：1)3~10kV系统电容电流不大于（），20kV及以上不大于10  A。
# 1
#   A.20  A             B.25  A
# 1
#   C.30  A             D.35  A
# 1
# 61.当电容电流大于（）后（建议参考值）消弧设备容量不足以补偿母线电容电流时，建议将中性点接地方式改为小电阻接地系统。   A.80  A             B.100  A
# 1
#   C.120  A            D.140  A
# 1
# 62.绝缘油颗粒数检测中，按仪器操作说明书，启动仪器，用合适的清洁液冲洗系统，冲洗至每100mL液体中粒径大于5µm的颗粒数，不应超过（）粒为合格。
# 1
#   A.70             B.80
# 1
#   C.90             D.100
# 1
# 63.绝缘油中T501抗氧化剂含量检测（红外光谱法）所用浓硫酸纯度为（）%
# 1
#   A.96             B.97
# 1
#   C.98             D.99
# 1
# 64.35kV及以下变压器绝缘油验收时击穿电压应不低于（）。
# 1
#   A.70kV               B.60kV
# 1
#   C.50kV               D.35kV
# 1
# 65.变压器绝缘绝缘油验收验收时的闪点应不小于（）℃。
# 1
#   A.135               B.140
# 1
#   C.145               D.150
# 1
# 66.110（66）kV-220kV变压器出厂验收时，变比的允许偏差在额定分接时为正负（）%。
# 1
#   A.0.2             B.0.3
# 1
#   C.0.4             D.0.5
# 1
# 67.220kV变压器出厂长时感应耐压试验,中压绕组局部放电量应不大于（）p  C。
# 1
#   A.100            B.200
# 1
#   C.300            D.500
# 1
# 68.断路器出厂验收检查，位置指示器的颜色和标示应符合相关标准要求，分、合闸指示牌应有（）个及以上定位螺栓固定以保证不发生位移
# 1
#   A.1              B.2
# 1
#   C.3              D.4
# 1
# 69.断路器机械特性测试时，操作电压在额定电源电压的（）%～（）%，断路器合闸装置应可靠动作。
# 1
#   A.80110           B.85110
# 1
#   C.80100           D.85100
# 1
# 70.断路器出厂验收要求，750kV断路器S  F6气体含水量的测定应在断路器充气（）小时后进行。
# 1
#   A.1               B.12
# 1
#   C.24              D.120
# 1
# 71.组合电器出厂主回路交流电压试验，126kV设备施加（）kV电压。
# 1
#   A.210             B.220
# 1
#   C.230             D.240
# 1
# 72.组合电器出厂验收，出厂时应逐台进行断路器（）测试，断路器应按照要求进行分合闸速度、分合时间、分合闸同期性等试验。
# 1
#   A.机械特性              B.低电压
# 1
#   C.刚分、刚合速度        D.主回路电阻
# 1
# 73.隔离开关出厂验收,隔离开关、接地开关底座上应装设不小于（）的接地螺栓。
# 1
#   A.M10                B.M12
# 1
#   C.M14                D.M16
# 1
# 74.隔离开关出厂验收，隔离开关接地开关可动部件与其底座之间的铜质软连接的截面积应不小于（）mm2。
# 1
#   A.50             B.40
# 1
#   C.30             D.20
# 1
# 75.隔离开关交接试验，导电回路电阻值测试值不应大于出厂值的（）倍。
# 1
#   A.1.1           B.1.2
# 1
#   C.1.3           D.1.4
# 1
# 76.隔离开关交接试验,绝缘子绝缘电阻不应低于（）MΩ。
# 1
#   A.1000             B.3000
# 1
#   C.5000             D.10000
# 1
# 77.隔离开关竣工（预）验收，采用垫片安装（厂家调节垫片除外）调节隔离开关水平的，支架或底架与基础的垫片不宜超过（）片，总厚度不应大于（）mm，且各垫片间应焊接牢固。
# 1
#   A.35                B.310
# 1
#   C.25                D.210
# 1
# 78.隔离开关操作电动机“（）”切换把手外观无异常，“（）”、“（）”把手外观无异常，操作功能正常，手动、电动操作正常；。  A.电动/手动、远方/就地、合闸/分闸
# 1
#   B.远方/就地、电动/手动、合闸/分闸
# 1
#   C.合闸/分闸、电动/手动、远方/就地
# 1
# 79.开关柜交接试验，24kV真空断路器合闸弹跳时间不应大于（）ms。
# 1
#   A.1             B.2
# 1
#   C.3             D.4
# 1
# 80.电流互感器交接试验，220kV电压等级电流互感器介质损耗角正切值t  Anδ应不大于（）%。
# 1
#   A.0.5            B.0.6
# 1
#   C.0.7            D.0.8
# 1
# 81.电流互感器交接试验，油浸式互感器在交流耐压试验前要保证静置时间，110（66）kV设备静置时间不小于（）h。
# 1
#   A.24             B.36
# 1
#   C.48             D.72
# 1
# 82.电压互感器出厂试验，中性点接地系统油浸式电压互感器在Um下局放量不大于（）。
# 1
#   A.5              B.10
# 1
#   C.20             D.50
# 1
# 83.电压互感器出厂试验，中性点接地系统油浸式电压互感器在1.2Um/√3下局放量不大于（）。
# 1
#   A.5               B.10
# 1
#   C.20              D.50
# 1
# 84.避雷器出厂试验,密封试验若采用热机试验或水煮试验，试验后试品外套部分不应有开裂或脱落现象，且试验前后无间隙金属氧化物避雷器的直流1m  A参考电压变化不大于（）%。
# 1
#   A.2                B.5
# 1
#   C.8                D.10
# 1
# 85.避雷器出厂试验,在1.05倍持续运行电压下的局部放电量应不大于（）p  C。
# 1
#   A.2                B.5
# 1
#   C.10               D.20
# 1
# 86.并联电容器出厂试验，10kV电压等级电容单元极对壳耐压试验电压值为（）kV。
# 1
#   A.42                  B.55
# 1
#   C.65                  D.70
# 1
# 87.并联电容器出厂试验，要求脉冲电流法局部放电试验数据在（）p  C以内。
# 1
#   A.5                  B.10
# 1
#   C.20                 D.50
# 1
# 88.电容器出厂试验验收时，单台电容值与额定值偏差应符合：有内熔丝：（）；无内熔丝：-5%～+5%。
# 1
#   A.负5%～正5%          B.负3%～正5%
# 1
#   C.负3%～正3%          D.负5%～正3%
# 1
# 89.在并联电容器组交接试验中，三相串联电抗器的直流电阻相间差值不应大于三相平均值的（）。
# 1
#   A.1%                 B.2%
# 1
#   C.3%                 D.4%
# 1
# 90.对10kV电抗器进行感应耐压试验，若电抗器额定耐受电压（），试验电压不出现突然下降为合格。
# 1
#   A.30kV               B.35kV
# 1
#   C.40kV               D.45kV
# 1
# 91.干式电抗器交接试验，相电抗器绕组直流电阻值相间差值不应大于三相平均值的（）%。
# 1
#   A.1                  B.2
# 1
#   C.3                  D.4
# 1
# 92.干式电抗器交接试验验收需对干式电抗器进行交流耐压试验，且要求按出厂试验电压值的（）进行耐压，1min，无击穿及闪络。
# 1
#   A.60%                 B.70%
# 1
#   C.80%                 D.90%
# 1
# 93.串联补偿装置出厂验收，电容器单元极对外壳绝缘电阻不应小于（）MΩ。
# 1
#   A.1000               B.2500
# 1
#   C.5000               D.10000
# 1
# 94.串联补偿装置出厂验收中的直流参考电压试验，每只MOV单元直流参考电压值不应低于（）。
# 1
#   A.制造厂实验值          B.制造厂设计值
# 1
#   C.制造厂规定值          D.制造厂宣称值
# 1
# 95.进行串联补偿装置交接试验，（）及以上的瓷支柱绝缘子应进行探伤检查无异常。
# 1
#   A.220kV             B.110kV
# 1
#   C.35kV              D.10kV
# 1
# 96.变电检测管理规定对变电设备检测职责分工、检测分类、检测周期、（）、检测准备、检测实施、检测验收、检测报告、检测分析等方面做出规定。
# 1
#   A.检测计划           B.检测策略
# 1
#   C.检测方法           D.检测目的
# 1
# 97.检测管理规定适用于公司系统（）kV及以上变压器（电抗器）、断路器、组合电器、隔离开关、开关柜、电流互感器、电压互感器、避雷器等28类设备和设施的检测工作。
# 1
#   A. 10               B.35
# 1
#   C.110               D.220
# 1
# 98.检测工作分为（）试验和（）检测两类。
# 1
#   A.停电、带电     B.带电、停电
# 1
#   C.停电、停电     D.带电、带电
# 1
# 99.带电检测工作出现以下情况时应适当增加检测频次：新投运的设备、对（）或主体进行解体性检修后重新投运的设备。
# 1
#   A.主要部件            B.核心部件
# 1
#   C.重要部件             D.本体部件
# 1
# 100.对于未开展带电检测设备，停电试验周期不大于基准周期的（）倍；未开展带电检测老旧设备（大于（）年运龄），停电试验周期不大于基准周期。
# 1
#   A.1.4、20              B.1.5、20
# 1
#   C.1.4、25               D.1.5、25
# 1
#
# 1
# 二、多选题(每题0.5分，计25分)
# 1
# 1.暂态地电压测试后应出具检测报告，对于存在异常的开关柜隔室，应附（  ）。
# 2
#   A.检测图片            B.检测数据
# 2
#   C.检测报告            D.缺陷分析
# 2
# 2.避雷器泄露电流测试应正确进行仪器设置，不包括（  ）等参数。
# 2
#   A .电压选取方式         B.电压互感器变比
# 2
#   C.信号同步方式          D.运行方式
# 2
# 3.变压器直流偏磁水平测试中需要详细记录有关测试的主变信息，主变接地点、主变接地情况、记录时间至少精确到分钟，读取直流值，并保存（  ）。
# 2
#   A.读数            B.波形
# 2
#   C.谐波分量        D.磁场大小
# 2
# 4.对进行变压器直流偏磁水平测量数据处理将直流单极大地运行时的（  ）进行相应的统计。
# 2
#   A.输送功率           B.测试时间
# 2
#   C.测试数据           D.变压器档位
# 2
# 5.直流高电压试验中，试品的表面应清洁干燥，试品在试验前不应受（  ）作用。
# 2
#   A.力的               B.机械的
# 2
#   C.光的               D.热的
# 2
# 6.直流高电压试验，为了限制试品放电时的放电电流，保护（  ）等，高压侧接取了保护电阻器。
# 2
#   A.硅堆               B.微安表
# 2
#   C.试验变压器         D.试品
# 2
# 7.直流高电压试验，多只硅堆串联时，使其电压分布均匀。通常宜采用（  ）的方法。
# 2
#   A.串联电容               B.并联电阻
# 2
#   C.并联电阻和电容         D.串联电阻和电容
# 2
# 8.直流高压试验计时结束后，降压断开电源。对有阶段降压要求的试验（如氧化物避雷器0.75Unm  A泄漏电流测量），先将电压降至预定值，并读取（  ），然后降压到零并断开电源。
# 2
#   A.泄漏电流              B.耐压时间
# 2
#   C.试验电压              D.电源电压
# 2
# 9.若两绝缘体之间的气隙放电，放电量与试验电压关系正确的选项是（  ）。
# 2
#   A.起始放电后，放电量随电压上升而稳定增长
# 2
#   B.熄灭电压基本相等或低于起始电压
# 2
#   C.起始放电后，放电量随电压上升而保持不变
# 2
#   D.熄灭电压高于起始电压
# 2
# 10.空载试验的试验电压的波形应为正弦波。为监视试验中电压波形，三相变压器与单相变压器空载试验时，均需测量电压（  ）。
# 2
#   A.峰值                  B.有效值
# 2
#   C.方均根值              D.平均值
# 2
# 11.测量短路阻抗的方法正确的选项是（  ）。
# 2
#   A.与开关的位置无关，不需要改变分接开关的位置
# 2
#   B.按选定的接线方式进行短路阻抗测量
# 2
#   C.应将被测绕组对的不加压侧所有接线端全部短接，被试品试验接线并检查确认接线正确
# 2
#   D.应将被测绕组对的不加压侧所有接线端全部开路，被试品试验接线并检查确认接线正确
# 2
# 12.支柱瓷绝缘子专用超声波探伤仪，该检测系统一般由（  ）及机械扫查装置等组成。
# 2
#   A.超声波检测仪         B.探头
# 2
#   C.试块                 D.耦合剂
# 2
# 13.电压比校核试验变压器的高压输出端应串接保护电阻器，可采用（  ）。
# 2
#   A.金属膜电阻器          B.水电阻器
# 2
#   C.线绕电阻器            D.碳膜电阻器
# 2
# 14.励磁特性测量成套设备,测量电压互感器励磁特性测量方式有（  ）。
# 2
#   A.一般测量               B.中性点接地系统
# 2
#   C.中性点不接地系统       D.中性点经电阻接地系统
# 2
# 15.在对  GIS电压互感器进行励磁特性试验时，由于( )等的作用，有时电压互感器一次侧带有部分容性负载，从而导致二次侧电流一部分用于电压互感器的励磁，另一部分用于容性负载的消耗，可能导致二次侧过载。
# 2
#   A.一次侧电阻               B.一次侧杂散电容
# 2
#   C.相间耦合电容              D.电感
# 2
# 16.主回路电阻测量仪器交流工作电源引线端与外壳之间承受1500V工频交流电压1min时，应不出现（  ）现象。
# 2
#   A.飞弧                  B.放电
# 2
#   C.闪络                  D.击穿
# 2
# 17.避雷器直流参考电压测试，根据避雷器串联叠装结构，分为哪几种接线方法（  ）。
# 2
#   A.常规试验接线          B.不拆高压引线试验接线
# 2
#   C.拆地线试验接线        D.不拆地线试验接线
# 2
# 18.接地引下线导通测试值在（  ）间的设备状况尚可，宜在以后例行测试中重点关注其变化，重要的设备宜在适当时候检查处理；在（  ）间的设备状况不佳，对重要的设备应尽快检查处理，其他设备宜在适当时候检查处理。
# 2
#   A.10mΩ-50mΩ           B.50mΩ-200mΩ
# 2
#   C.200mΩ-1Ω            D.1Ω-2Ω
# 2
# 19.接地阻抗测量，如电流极电阻偏高，可尝试采用（  ）的方式降阻。
# 2
#   A.多个电流极并联       B.多个电流极串联
# 2
#   C.多个电压级并联       D.向其周围泼水
# 2
# 20.土壤电阻率测试的四极法适用于（  ）。
# 2
#   A.测试被试电极较远地区的土壤
# 2
#   B.测试被试电极较大区域的土壤
# 2
#   C.水平分层不均匀的土壤特性
# 2
#   D.垂直分层不均匀的土壤特性
# 2
# 21.测量接触电压时，测试电流应从（  ）注入接地装置。
# 2
#   A.构架                 B.电气设备外壳
# 2
#   C.地网中心             D.地网底部
# 2
# 22.跨步电压和接触电压测量中，可采用（  ）作为电流极，但应注意避雷线分流的影响。
# 2
#   A.高压输电线路的铁塔      B.避雷器
# 2
#   C.架构                  D.人工接地极
# 2
# 23.现场污秽度评估时，对于不带电的参照绝缘子，应取第（  ）的平均等值盐密和灰密作为该串的等值盐密和灰密。
# 2
#   A.2                     B.3
# 2
#   C.4                     D.5
# 2
# 24.以下是220kV电压等级绝缘子绝缘电阻测试结果，可以判断为劣化绝缘子的为（  ）。
# 2
#   A.100MΩ                B.200MΩ
# 2
#   C.400MΩ                D.500MΩ
# 2
# 25.硅橡胶憎水性分级为（  ）的可以继续运行。
# 2
#   A.H  C3                  B.H  C4
# 2
#   C.H  C5                  D.H  C6
# 2
# 26.硅橡胶的憎水性检测时，选择停电设备的一相瓷瓶或一只复合绝缘子做测试点，取该串绝缘子（支柱瓷瓶、套管、绝缘子等）的（  ）做检测。
# 2
#   A.基座（低压侧）第二片            B.中间一片
# 2
#   C.导线侧（高压侧）第二片做检测    D.高压侧第一片
# 2
# 27.机械弯曲破坏负荷试验中试验机应满足如下哪些要求（  ）。
# 2
#   A.试验机两端法兰连接块应相互平行，连接块硬度大于等于55HR  C
# 2
#   B.试验机两端法兰连接块应相互垂直，连接块硬度大于等于55HR  C
# 2
#   C.试验机的试验速率应能调节控制，并有自动记录负荷的功能
# 2
#   D.试验机应采用悬臂梁弯曲方式，弯曲压头宽度应满足相关产品标准要求
# 2
# 28.孔隙性试验步骤包括（  ）。
# 2
#   A.试样浸入溶剂           B.洗涤
# 2
#   C.干燥                   D.敲碎
# 2
# 29.以下是绝缘油酸值检测结果，试验结果合格的是（  ）。
# 2
#   A.0.03m  G（KOH）/  G         B.0.05m  G（KOH）/  G
# 2
#   C.0.08m  G（KOH）/  G          D.1m  G（KOH）/  G
# 2
# 30.以下是全自动绝缘油击穿电压测定仪电极间距，符合标准要求的是（  ）。
# 2
#   A.2.43                     B.2.51
# 2
#   C.2.53                     D.2.56
# 2
# 31.以下是全自动绝缘油击穿电压测定仪电极的球形直径，符合要求的是（  ）。
# 2
#   A.12mm                B.12.5mm
# 2
#   C.13mm                D.13.5mm
# 2
# 32.气相色谱仪应具备哪些设备（  ）。
# 2
#   A.热导检测器          B.氢焰离子化检测器
# 2
#   B.  C.镍触媒转化炉      D.脱气装置
# 2
# 33.绝缘油介质损耗测试时，干燥电极杯的烘箱温度可以设置为（  ）℃。
# 2
#   A.100               B.105
# 2
#   C.110               D.120
# 2
# 34.以下是绝缘油界面张力检测所用铂圆环的周长，满足要求的是（  ）。  A.40mm              B.50mm
# 2
#   C.60mm              D.70mm
# 2
# 35.绝缘油中T501抗氧化剂含量检测（红外光谱法）所用红外分光光度计波长范围应涵盖（  ）  Cm-1。
# 2
#   A.3900               B.3800
# 2
#   C.3700               D.3600
# 2
# 36.绝缘油体积电阻率检测需要使用的试剂包括（  ）。
# 2
#   A.石油醚               B.正庚烷
# 2
#   C.磷酸三钠           D.蒸馏水
# 2
# 37.母线电容电流检测主要技术指标有:（  ）。 检测电流范围:
# 2
#   A.1  A~200  A                 B.满足抗干扰性能要求
# 2
#   C.分辨率：不大于0.01  A     D.检测频率范围：20Hz~200Hz
# 2
# 38.变压器绝缘油验收时油中颗粒度：①1000kV（750kV）：5μm-100μm的颗粒度≤（  ）；无100μm以上的颗粒；②500kV及以上：大于5μm的颗粒度≤（  ）。
# 2
#   A. 1000/100mL          B.1500/100mL
# 2
#   C.2000/100mL           D.3000/100Ml
# 2
# 39.500（330）kV-1000kV变压器出厂验收时,负载损耗应在（  ）分接位置上进行，数值应满足投标技术规范书要求。
# 2
#   A.最大               B.最小
# 2
#   C.额定               D.所有
# 2
# 40.变压器出厂试验对套管电流互感器可只进行（  ）测试。
# 2
#   A.变比               B.饱和曲线         C.极性
# 2
#   D.直阻               E.绝缘试验
# 2
# 41.110（66）kV-220kV变压器出厂验收时,应测量每一绕组对地及其余绕组间（  ）绝缘电阻值，并记录测量温度。
# 2
#   A.15s              B.60s
# 2
#   C.5min             D.10min
# 2
# 42.110（66）kV-220kV变压器出厂验收,（  ）需要进行外施工频耐压试验。
# 2
#   A.高压线圈          B.中压线圈
# 2
#   C.低压线圈          D.中性点
# 2
# 43.110（66）kV-220kV变压器出厂短时感应耐压试验，对于三相变压器，要求进行（  ）。
# 2
#   A. 带有局部放电测量的相对地试验
# 2
#   B.带有局部放电测量的中性点接地的相间试验
# 2
#   C.不带局部放电测量的相对地试验
# 2
#   D.不带局部放电测量的中性点接地的相间试验
# 2
# 44.断路器出厂验收，断路器各断口均压电容器其（  ）应符合产品技术规范。
# 2
#   A.交流耐压值      B.绝缘电阻值
# 2
#   C.电容值          D.介损
# 2
# 45.断路器出厂验收，断路器弹簧机构储能电机应配有（  ）等保护元件，整定值应符合产品技术要求。
# 2
#   A. 储能超时         B.储能不足          C.过流
# 2
#   D.低压              E.热偶
# 2
# 46.断路器出厂验收，断路器弹簧机构的验收项目有（  ）。
# 2
#   A. 传动链条无锈蚀
# 2
#   B.机构各转动部分应涂以适合当地气候条件的润滑脂
# 2
#   C.缓冲器缓冲行程符合制造厂规定
# 2
#   D.弹簧机构内轴销、卡簧等应齐全，螺栓应紧固，并画划线标记
# 2
# 47.组合电器出厂验收，  GIS设备内部的（  ）等部件，必须经过局部放电试验方可装配。
# 2
#   A.绝缘操作杆               B.盆式绝缘子
# 2
#   C.支撑绝缘子               D.导电杆
# 2
# 48.组合电器试验验收中气体密封性试验应:（  ）。
# 2
#   A.组合电器静止24小时后进行
# 2
#   B.组合电器静止48小时后进行
# 2
#   C.采用检漏仪对各气室密封部位、管道接头等处进行检测时，检漏仪不应报警
# 2
#   D.每一个气室年漏气率不应大于0.5%
# 2
#   E.每一个气室年漏气率不应大于1%
# 2
# 49.隔离开关出厂验收，隔离开关和接地开关及其操动机构应分别在（  ）进行机械特性试验，操作应无故障。
# 2
#   A.100%Un                  B.110%Un
# 2
#   C.85%Un                   D.80%Un
# 2
# 50.下列哪些是开关柜交接试验验收标准卡内容（  ）。
# 2
#   A.隔离开关试验验收
# 2
#   B.断路器试验验收
# 2
#   C.开关柜整体试验验收
# 2
#   D.S  F6充气柜特殊验收
# 2
#   E.试验对比分析
# 2
#
# 2
# 三、判断题(每题0.5分，计20分)
# 2
# 1.绝缘油水分检测（库仑法）所用的电解液应放在阴凉，干燥，暗处环境下保存。(  )
# 3
# 2.高效液相色谱仪应符合双泵或单泵系统，C18液相色谱柱，柱长150mm，能检测紫外线(UV)光谱的UV检测器，能检测红外光谱的检测器等条件。(  )
# 3
# 3.液相色谱仪的流量，0.2mL/min，0.4mL/min，0.6mL/min，0.8mL/min均符合要求。(  )
# 3
# 4.绝缘油中T501抗氧化剂含量检测（红外光谱法）所用仪器设备包括红外分光光度计，液体吸收池，玻璃注射器，搅拌器。(  )
# 3
# 5.全自动绝缘油体积电阻率测试仪支撑电极的绝缘材料应具有较好机械强度，高体积电阻率，低体积电阻率，高介质损耗因数等性能。(  )
# 3
# 6.全自动绝缘油体积电阻率测试仪应具有自检，自校，自诊断，空杯电容测试功能。(  )
# 3
# 7.绝缘油颗粒数检测，待测样品要求:用洁净的250ml专用颗粒污染度取样瓶，从设备下部取样口采样250ml;油样在运输、保管过程中要注意样品的防尘、防震、避光和干燥等。(  )
# 3
# 8.绝缘油铜金属含量测量用的设备通常有等离子发射光谱仪，高温炉，红外调温电热板，电热鼓风干燥箱、可调电炉、精密天平等。(  )
# 3
# 9.母线电容电流检测验收：检查数据是否准确、完整;检测完毕后，进行现场清理，确保无遗漏;测试结束后，退出电压互感器，拆除消谐器上的短接线，然后将母线电压互感器恢复运行;继续进行其它母线的电容电流测量。(  )
# 3
# 10.110kV变压器出厂验收时，高电压冲击试验验收包含线端操作冲击试验（SI），线端雷电全波冲击试验（LI），外施工频耐压试验，短时感应耐压试验（ACSD）。(  )
# 3
# 11.35kV变压器出厂验收时,短路阻抗应在最大，最小，额定，所有分接位置上进行，数值应满足投标技术规范书要求。(  )
# 3
# 12.35kV变压器出厂验收, 高压线圈，中压线圈，低压线圈，中性点需要进行外施工频耐压试验。(  )
# 3
# 13.断路器出厂验收，断路器辅助开关与机构间的连接应辅助开关与机构间的连接应松紧适当、转换灵活;应能满足通电时间的要求;连接锁紧螺帽应拧紧，并应采取放松措施。(  )
# 3
# 14.组合电器交接试验验收中主回路电阻试验应采用电流不小于100A的直流压降法，现场测试值不得超过控制值Rn(Rn是产品技术条件规定值)，应注意与出厂值的比较，不得超过出厂实测值的120%，注意三相测试值的平衡度，如三相测量值存在明显差异，须查明原因，测试应涵盖所有电气连接。(  )
# 3
# 15.断路器试验验收，绝缘子试验验收，绝缘护套试验验收，S  F6充气柜验收，开关柜整体试验验收是开关柜出厂验收（试验）标准卡内容。(  )
# 3
# 16.电压互感器交接试验,电磁式电压互感器励磁曲线测量点电压为20%，50%，80%，100%，120%。(  )
# 3
# 17.避雷针在到货验收中发现质量问题时，验收人员应及时告知项目管理部门，设备运行管理单位，物资部门，制程厂家，提出整改意见，并填入“到货验收记录”。(  )
# 3
# 18.避雷针制造厂提供的主要材料检验报告包括：钢材性能检测报告;钢材化学成分分析报告;焊材质量检测报告;锌锭化学成分分析报告;螺栓（螺母）质量检测报告质量检测报告等。(  )
# 3
# 19.站用直流电源系统竣工（预）验收标准卡中，充电装置检查验收的控制程序试验验收标准为试验控制充电装置应能自动进行恒流限压充电→恒压充电→浮充电运行状态切换;试验充电装置应具备自动恢复功能，装置停电时间超过10分钟后，能自动实现恒流充电→恒压充电→浮充电工作方式切换;恒流充电时，充电电流的调整范围为20%In～130%In（In－额定电流）;恒压运行时，充电电流的调整范围为0～100%In。(  )
# 3
# 20.耦合电容器竣工（预）验收标准卡中，外观验收的设备安装验收标准为各零、部件装配应牢固无松动;耦合电容器安装时，不应松动其顶盖上的紧固螺栓;耦合电容器叠装时中心线一致，无歪扭倾斜现象;两节或多节耦合电容器叠装时，应按制造厂的编号安装，不得互换。(  )
# 3
# 21.中性点电容隔直装置出厂验收，装置功能需要满足基本功能满足设计要求;晶闸管门槛电压检验（如有）;定值修改功能验收满足设计要求、运行日志获取查看功能满足设计要求、录波功能满足设计要求;历史/实时曲线浏览功能满足设计要求、通讯中断功能试验满足设计要求。(  )
# 3
# 22.对中性点电容隔直装置环境验收验收有下列要求：装置与接地开关之间加装绝缘挡;装置室内地面铺绝缘垫;装置室应设除湿空调（必要时），温湿度指示计;装置室电缆进出口封堵良好。(  )
# 3
# 23.串联补偿装置出厂验收中的金属氧化物限压器（MOV）试验中，电流分布试验的验收标准为同一单元每柱之间的分流系数应不大于1.05;MOV单元之间的分流系数不大于1.03;串联在一起使用的MOV电阻片柱分流系数应不大于1.02;并联在一起使用的MOV电阻片柱分流系数应不大于1.1。(  )
# 3
# 24.对干式电抗器绝缘电阻出厂验收要求有使用2500V兆欧表摇测，绕组绝缘电阻不小于1000MΩ;使用2500V兆欧表摇测，绕组绝缘电阻不小于1500MΩ;使用500V兆欧表摇测，铁心对夹件及地绝缘电阻不小于100MΩ;使用500V兆欧表摇测，铁心对夹件及地绝缘电阻不小于200MΩ。(  )
# 3
# 25.避雷器交接试验本体绝缘电阻应使用35kV以上：采用5000V兆欧表，不小于2500MΩ;35kV及以下：采用2500V兆欧表，不小于1000MΩ兆欧表。(  )
# 3
# 26.110（66）kV-220kV变压器出厂短时感应耐压试验，对于三相变压器，要求进行带有局部放电测量的相对地试验;带有局部放电测量的中性点接地的相间试验;不带局部放电测量的相对地试验;不带局部放电测量的中性点接地的相间试验。(  )
# 3
# 27.500（330）kV-1000kV变压器出厂验收, 高压线圈;中压线圈;低压线圈;中性点需要进行外施工频耐压试验。(  )
# 3
# 28.孔隙性试验前准备工作包括应详细了解设备的运行情况，据此制定相应的技术措施;应配备与工作情况相符的上次试验报告、标准作业卡、工具和连接导线等;检查环境、人员、工具满足取样条件;按相关安全生产管理规定办理工作许可手续。(  )
# 3
# 29.绝缘油酸值计算需要知道滴定试油所消耗的氢氧化钾乙醇溶液的体积;滴定空白所消耗的氢氧化钾乙醇溶液的体积;氢氧化钾乙醇溶液的浓度;试油的重量等参数。(  )
# 3
# 30.绝缘油含气量检测所用的标准气体采用二级标准物质;具有组分浓度含量;具有检验合格证;具有有效使用日期。(  )
# 3
# 31.直流高压试验对试验电压的要求是电压满足相应试品直流试验要求;必须具有充分的电源容量;通常采用负极性;在输出工作电流下，直流电压的纹波因数不大于3%。(  )
# 3
# 32.绝缘电阻测试试验数据需要同同一设备的各相的数据;出厂试验数据;耐压前后数据;历次同温度下的数据比较等数据比较，结合其他试验综合判断。(  )
# 3
# 33.开展短路阻抗试验，试验前准确测量或计算绕组平均温度;三绕组变压器，短路阻抗应在成对的绕组间进行测量;试验时，非被试绕组短路;测试结果出现异常时，应对所有绕组对用三相法进行复测。(  )
# 3
# 34.测量变压器变比试验步骤是：试验前对试品进行充分的放电;变比测试仪的接地端子进行接地;按试验项目要求将待试设备与试验仪器接线;待出现测试数据后，记录数据，按复位键复位，当为多档位调压时，则换挡对各档位都应进行测试;测试完后，按复位键复位，关闭电源。(  )
# 3
# 35.电流比校核中，对采用一次绕组抽头改变电流比时，应对使用电流比进行校核，电流比校核中，对采用二次绕组抽头改变电流比时，应对每组抽头进行变比校核。(  )
# 3
# 36.电压互感器变压比测量的设备通常是变压比测量成套仪器;试验变压器;调压设备;标准电压互感器;电压测量装置。(  )
# 3
# 37.励磁特性测量对待试设备要求待试设备处于冷备用状态;设备外观清洁、无异常;设备上无各种外部作业;电压互感器和电流互感器一、二次未与其他设备连接;励磁特性测量要求电压互感器和电流互感器一、二次未与其他设备连接。(  )
# 3
# 38.主回路电阻测量对于S  F6断路器、油断路器、真空断路器、高压开关柜内用断路器，应在设备合闸并可靠导通的情况下，测量每相的回路电阻值;主回路电阻测量，对于  GIS，若有进出线套管，可利用进出线套管注入测量电流进行测量;若  GIS接地开关导电杆与外壳绝缘，引到金属外壳的外部以后再接地，测量时可将活动接地片打开，利用回路上的两组接地开关导电杆关合到测量回路上进行测量;若接地开关导电杆与外壳不绝缘时，可先测量导体与外壳的并联电阻R0和外壳的直流电阻R1，然后按公式R=R0R1/(R1+R0)换算回路电阻R。(  )
# 3
# 39.泄漏电流检测，电流取样方式有串接法;钳形电流传感器法。(  )
# 3
# 40.外施交流耐压试验中，在选用试验变压器时，主要应考虑电压，电流，频率。(  )
# 3
#
# 3
# 四、问答题(每题6分，计30分)
# 3
# 1.简述现场污秽度评估方法?
# 4
#
# 4
#
# 4
#
# 4
#
# 4
#
# 4
#
# 4
#
# 4
#
# 4
#
# 4
#
# 4
#
# 4
# 2. 简述绝缘油击穿电压检测安全要求 ?
# 4
#
# 4
#
# 4
#
# 4
#
# 4
#
# 4
#
# 4
#
# 4
#
# 4
#
# 4
#
# 4
# 3. 绝缘油体积电阻率检测注意事项?
# 4
#
# 4
#
# 4
#
# 4
#
# 4
#
# 4
#
# 4
#
# 4
#
# 4
#
# 4
#
# 4
# 4.绝缘油铜金属含量检测方法 ?
# 4
#
# 4
#
# 4
#
# 4
#
# 4
#
# 4
#
# 4
#
# 4
#
# 4
#
# 4
#
# 4
# 5. 红外成像严重缺陷是如何定义的？
# 4
#
# 4
#
# 4
#
# 4
#
# 4
#
# 4
#
# 4
#
# 一、单选
# 4
# 1-5.AABAB  6-10.BBABC  11-15.CBBBC  16-20.DABAC  21-25.BADCC  26-30.BBDAB  31-35.AACAA  36-40.ACDBA  41-45.AABBC  46-50.ACDAB  51-55.BBACD  56-60.ADCDC  61-65.BDCDA  66-70.DABBD  71-75.CABAB  76-80.ABABB  81-85.ABABC  86-90.ADBBB  91-95.BCBDB  96-100.ABABA
# 4
# 二、多选
# 4
# 1.AD  2.CD  3.ABC  4.ABC   5.BD  6.ABC  7.BC  8.AC  9.AB  10.CD  11.BC  12.ABCD  13.BC  14.ABC  15.BC  16.AD  17.AB  18.BC  19.AD  20.ABCD  21.AB  22.AD  23.ABC  24.AB  25.ABC  26.ABC  27.ACD  28.ABCD  29.ABC  30.BC  31.BC  32.ABC  33.BC  34.ABC  35.BCD  36.ABCD  37.ABCD  38.AC  39.AC  40.ABCDE  41.ABD  42.CD  43.AB  44.BCD  45.ACE  46.ABCD  47.ABC  48.ACD  49.ABC  50.BCDE
# 4
# 三、判断
# 4
# 1-5.√××√×  6-10.√√√×√  11-15.××√√×  16-20.√×√√√  21-25.√√××√  26-30.××√√√  31-35.√√×√√  36-40.√××××
# 4
# 四、简答题
# 4
# 1.简述现场污秽度评估方法?
# 4
# 现场污秽度的评估可以根据置信度值递减按以下顺序进行：
# 4
# a) 变电站绝缘子的运行经验与污秽测量资料；
# 4
# b) 现场等值盐密、灰密测量值及现场污秽度监测；
# 4
# c) 按气候和环境条件模拟计算污秽水平；
# 4
# d) 根据典型环境的污湿特征预测现场污秽度。
# 4
# 2. 简述绝缘油击穿电压检测安全要求 ?
# 4
# a) 执行国家电网公司《电力安全工作规程（变电部分）》相关要求。
# 4
# b) 现场取样至少由2人进行。
# 4
# c) 仪器接地应良好。
# 4
# d) 测试过程中禁止触动仪器高压罩，以防高电压伤人。
# 4
# e) 试验仪器未放置油样时，禁止升压。
# 4
# f) 试验人员应站在绝缘垫上进行操作。
# 4
# g) 在更换油样时应切断电源。
# 4
# h) 在装样操作时不许用手触及电源及电极、油杯内部和试油。
# 4
# 3. 绝缘油体积电阻率检测注意事项?
# 4
# a) 如果在该试样上已测过介质损耗因数，则测量电阻率之前应短接两电极60s。
# 4
# b) 应在规定的温度、电场强度、加压时间下进行测定。
# 4
# c) 油杯的清洁程度对测试结果有显著影响，检测时油杯一定要清洗干净。
# 4
# 4.绝缘油铜金属含量检测方法 ?
# 4
# 首先将油样品加热蒸干、灰化处理以后，然后用盐酸（1+1）溶解，在硝酸（2＋98）的介质中，用等离子发射光谱仪进行测定，从而确定油中金属元素的含量。
# 4
# 5. 红外成像严重缺陷是如何定义的？
# 4
# a) 指设备存在过热，程度较重，温度场分布梯度较大，温差较大的缺陷。这类缺陷应尽快安排
# 4
# 处理。
# 4
# b) 对电流致热型设备，应采取必要的措施，如加强检测等，必要时降低负荷电流。
# 4
# c) 对电压致热型设备，应加强监测并安排其他测试手段，缺陷性质确认后，立即采取措施消缺。
# 4
# d) 电压致热型设备的缺陷一般定为严重及以上的缺陷。
# 4
#
# 4
#
# 4
#
# 4
